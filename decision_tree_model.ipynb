# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.14.0

# %%
#necessary imports
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

# %%
#import dataset
df = pd.read_csv('./data/dataset.csv')
df.head()
# Out:
#    Unnamed: 0  home_last_3_P  home_last_3_OppP  home_last_3_FG  \
# 0           0         112.33            106.33           42.33
# 1           0         110.67            114.33           41.33
# 2           0         113.67            113.33           44.00
# 3           0         116.33            117.67           44.33
# 4           0         120.67            112.33           43.00
#
#    home_last_3_FGA  home_last_3_FG%  home_last_3_3P  home_last_3_3PA  \
# 0            84.67             0.50           11.33            31.33
# 1            90.67             0.46           11.33            31.33
# 2            92.67             0.48           10.33            29.00
# 3            95.33             0.47           14.33            38.00
# 4            89.00             0.49           13.33            31.33
#
#    home_last_3_3P%  home_last_3_FT  ...  away_last_50_DeFG%  \
# 0             0.36           16.33  ...                0.51
# 1             0.34           16.67  ...                0.53
# 2             0.34           15.33  ...                0.53
# 3             0.39           13.33  ...                0.50
# 4             0.42           21.33  ...                0.54
#
#    away_last_50_DTOV%  away_last_50_DDRB%  away_last_50_DFT/FGA  \
# 0               12.67               76.90                  0.18
# 1               11.26               77.10                  0.21
# 2               11.25               75.18                  0.17
# 3               11.99               76.40                  0.16
# 4               13.79               74.56                  0.21
#
#    away_last_50_W  away_last_50_H        Date  Home_Team  Away_Team  \
# 0            41.0            27.0  2022-02-03        ATL        PHO
# 1            18.0            26.0  2022-02-08        ATL        IND
# 2            19.0            26.0  2022-02-11        ATL        SAS
# 3            32.0            25.0  2022-02-15        ATL        CLE
# 4            27.0            24.0  2022-02-26        ATL        TOR
#
#    Home_Team_Won
# 0           True
# 1           True
# 2          False
# 3           True
# 4           True
#
# [5 rows x 233 columns]

# %%
#We want clean the data and split up the input and output
target_column = "Home_Team_Won"
unneeded_columns = ["Date",	"Home_Team", "Away_Team"]

#remove first column from dataset
df = df.drop(df.columns[[0]],axis = 1)

#remove unneed_columns. These are columns that are in our dataset, but we don't want to feed into the model
#this is because they are categorical, we're only feeding our model numerical data
clean_df = df.drop(columns=unneeded_columns, axis=1)

# making new data frame with dropped NA values
clean_df = clean_df.dropna(axis=0, how='any')

#get the output rows of the dataset
output_rows = clean_df[target_column]

#remove output rows from the dataset
clean_df = clean_df.drop(columns=target_column, axis=1)

clean_df.head()
# Out:
#    home_last_3_P  home_last_3_OppP  home_last_3_FG  home_last_3_FGA  \
# 0         112.33            106.33           42.33            84.67
# 1         110.67            114.33           41.33            90.67
# 2         113.67            113.33           44.00            92.67
# 3         116.33            117.67           44.33            95.33
# 4         120.67            112.33           43.00            89.00
#
#    home_last_3_FG%  home_last_3_3P  home_last_3_3PA  home_last_3_3P%  \
# 0             0.50           11.33            31.33             0.36
# 1             0.46           11.33            31.33             0.34
# 2             0.48           10.33            29.00             0.34
# 3             0.47           14.33            38.00             0.39
# 4             0.49           13.33            31.33             0.42
#
#    home_last_3_FT  home_last_3_FTA  ...  away_last_50_OeFG%  \
# 0           16.33            22.67  ...                0.54
# 1           16.67            19.67  ...                0.52
# 2           15.33            17.67  ...                0.52
# 3           13.33            15.33  ...                0.54
# 4           21.33            27.33  ...                0.51
#
#    away_last_50_OTOV%  away_last_50_OORB%  away_last_50_OFT/FGA  \
# 0               11.55               22.63                  0.18
# 1               11.71               25.02                  0.18
# 2               10.79               24.07                  0.15
# 3               12.56               23.80                  0.19
# 4               10.69               27.32                  0.18
#
#    away_last_50_DeFG%  away_last_50_DTOV%  away_last_50_DDRB%  \
# 0                0.51               12.67               76.90
# 1                0.53               11.26               77.10
# 2                0.53               11.25               75.18
# 3                0.50               11.99               76.40
# 4                0.54               13.79               74.56
#
#    away_last_50_DFT/FGA  away_last_50_W  away_last_50_H
# 0                  0.18            41.0            27.0
# 1                  0.21            18.0            26.0
# 2                  0.17            19.0            26.0
# 3                  0.16            32.0            25.0
# 4                  0.21            27.0            24.0
#
# [5 rows x 228 columns]

# %%
#we cleaned up our data, now we are going to split it and get it ready to feed into the model
X_train, X_test, y_train, y_test = train_test_split(clean_df, output_rows, test_size=0.25, random_state=0)

#now we have our training and testing dataset
print('X_train:',np.shape(X_train))
print('y_train:',np.shape(y_train))
print('X_test:',np.shape(X_test))
print('y_test:',np.shape(y_test))
# Out:
# X_train: (1274, 228)
# y_train: (1274,)
# X_test: (425, 228)
# y_test: (425,)

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)


# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5411764705882353

# %%
#e valuate the results
y_pred = clf.predict(X_test)

# Create the confusion matrix
cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();

# %%
#print image of tree
import matplotlib.pyplot as plt
from sklearn import tree

plt.figure(figsize=(24,24))
tree.plot_tree(clf, feature_names= X_test.columns.to_list(), fontsize=6)
# plt.savefig('tree_high_dpi', dpi=100)
# Out:
# [Text(0.2655746987674761, 0.9782608695652174, 'home_last_50_W <= 18.5\ngini = 0.492\nsamples = 1274\nvalue = [557, 717]'),
#  Text(0.13566961000735836, 0.9347826086956522, 'away_last_50_TRB <= 45.78\ngini = 0.453\nsamples = 237\nvalue = [155, 82]'),
#  Text(0.1020971302428256, 0.8913043478260869, 'away_last_3_FGA <= 92.835\ngini = 0.476\nsamples = 205\nvalue = [125, 80]'),
#  Text(0.05261221486387049, 0.8478260869565217, 'away_last_50_DDRB% <= 74.695\ngini = 0.453\nsamples = 182\nvalue = [119, 63]'),
#  Text(0.017660044150110375, 0.8043478260869565, 'home_last_3_TS% <= 0.575\ngini = 0.454\nsamples = 23\nvalue = [8, 15]'),
#  Text(0.01177336276674025, 0.7608695652173914, 'home_last_10_DDRB% <= 72.405\ngini = 0.278\nsamples = 18\nvalue = [3, 15]'),
#  Text(0.005886681383370125, 0.717391304347826, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.017660044150110375, 0.717391304347826, 'away_last_10_TRB <= 46.85\ngini = 0.117\nsamples = 16\nvalue = [1, 15]'),
#  Text(0.01177336276674025, 0.6739130434782609, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.0235467255334805, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0235467255334805, 0.7608695652173914, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.0875643855776306, 0.8043478260869565, 'home_last_10_FGA <= 86.25\ngini = 0.422\nsamples = 159\nvalue = [111, 48]'),
#  Text(0.052980132450331126, 0.7608695652173914, 'away_last_3_AST% <= 64.265\ngini = 0.494\nsamples = 38\nvalue = [17, 21]'),
#  Text(0.041206769683590876, 0.717391304347826, 'away_last_3_OORB% <= 17.62\ngini = 0.365\nsamples = 25\nvalue = [6, 19]'),
#  Text(0.03532008830022075, 0.6739130434782609, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.047093451066961, 0.6739130434782609, 'away_last_3_OFT/FGA <= 0.175\ngini = 0.236\nsamples = 22\nvalue = [3, 19]'),
#  Text(0.041206769683590876, 0.6304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.052980132450331126, 0.6304347826086957, 'home_last_10_DeFG% <= 0.585\ngini = 0.095\nsamples = 20\nvalue = [1, 19]'),
#  Text(0.047093451066961, 0.5869565217391305, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(0.05886681383370125, 0.5869565217391305, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06475349521707138, 0.717391304347826, 'away_last_10_OppP <= 120.65\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.05886681383370125, 0.6739130434782609, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.0706401766004415, 0.6739130434782609, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.12214863870493009, 0.7608695652173914, 'home_last_50_STL% <= 7.065\ngini = 0.347\nsamples = 121\nvalue = [94, 27]'),
#  Text(0.094186902133922, 0.717391304347826, 'away_last_50_STL% <= 7.795\ngini = 0.492\nsamples = 32\nvalue = [18, 14]'),
#  Text(0.08241353936718175, 0.6739130434782609, 'home_last_10_AST% <= 60.13\ngini = 0.386\nsamples = 23\nvalue = [17, 6]'),
#  Text(0.07652685798381163, 0.6304347826086957, 'away_last_3_FGA <= 89.165\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.0706401766004415, 0.5869565217391305, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.08241353936718175, 0.5869565217391305, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.08830022075055188, 0.6304347826086957, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.10596026490066225, 0.6739130434782609, 'away_last_10_FT <= 19.7\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.10007358351729213, 0.6304347826086957, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.11184694628403238, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15011037527593818, 0.717391304347826, 'home_last_10_Pace <= 103.09\ngini = 0.249\nsamples = 89\nvalue = [76, 13]'),
#  Text(0.14422369389256806, 0.6739130434782609, 'away_last_50_P <= 111.07\ngini = 0.206\nsamples = 86\nvalue = [76, 10]'),
#  Text(0.12362030905077263, 0.6304347826086957, 'home_last_50_FT% <= 0.775\ngini = 0.417\nsamples = 27\nvalue = [19, 8]'),
#  Text(0.11184694628403238, 0.5869565217391305, 'home_last_3_DDRB% <= 80.635\ngini = 0.255\nsamples = 20\nvalue = [17, 3]'),
#  Text(0.10596026490066225, 0.5434782608695652, 'home_last_50_STL <= 8.01\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(0.10007358351729213, 0.5, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.11184694628403238, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1177336276674025, 0.5434782608695652, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13539367181751288, 0.5869565217391305, 'away_last_3_OORB% <= 20.25\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.12950699043414277, 0.5434782608695652, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.141280353200883, 0.5434782608695652, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.1648270787343635, 0.6304347826086957, 'away_last_10_BLK <= 6.25\ngini = 0.065\nsamples = 59\nvalue = [57, 2]'),
#  Text(0.15894039735099338, 0.5869565217391305, 'away_last_3_Pace <= 102.82\ngini = 0.034\nsamples = 58\nvalue = [57, 1]'),
#  Text(0.15305371596762327, 0.5434782608695652, 'gini = 0.0\nsamples = 57\nvalue = [57, 0]'),
#  Text(0.1648270787343635, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17071376011773362, 0.5869565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15599705665930833, 0.6739130434782609, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.1515820456217807, 0.8478260869565217, 'away_last_10_FGA <= 92.25\ngini = 0.386\nsamples = 23\nvalue = [6, 17]'),
#  Text(0.13980868285504047, 0.8043478260869565, 'away_last_10_DDRB% <= 72.985\ngini = 0.117\nsamples = 16\nvalue = [1, 15]'),
#  Text(0.13392200147167035, 0.7608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1456953642384106, 0.7608695652173914, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.16335540838852097, 0.8043478260869565, 'home_last_10_Pace <= 101.765\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.15746872700515085, 0.7608695652173914, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.1692420897718911, 0.7608695652173914, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1692420897718911, 0.8913043478260869, 'home_last_3_OORB% <= 28.465\ngini = 0.117\nsamples = 32\nvalue = [30, 2]'),
#  Text(0.16335540838852097, 0.8478260869565217, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(0.1751287711552612, 0.8478260869565217, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.39547978752759383, 0.9347826086956522, 'home_last_50_DDRB% <= 75.725\ngini = 0.475\nsamples = 1037\nvalue = [402, 635]'),
#  Text(0.29065489330389993, 0.8913043478260869, 'away_last_50_FT% <= 0.815\ngini = 0.498\nsamples = 260\nvalue = [138, 122]'),
#  Text(0.2398822663723326, 0.8478260869565217, 'home_last_10_ORtg <= 114.475\ngini = 0.5\nsamples = 223\nvalue = [108, 115]'),
#  Text(0.20456217807211186, 0.8043478260869565, 'home_last_50_FG <= 40.05\ngini = 0.45\nsamples = 82\nvalue = [54, 28]'),
#  Text(0.188373804267844, 0.7608695652173914, 'away_last_3_3PAr <= 0.37\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.18248712288447388, 0.717391304347826, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.19426048565121412, 0.717391304347826, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.22075055187637968, 0.7608695652173914, 'away_last_50_DeFG% <= 0.555\ngini = 0.392\nsamples = 71\nvalue = [52, 19]'),
#  Text(0.20603384841795438, 0.717391304347826, 'home_last_3_DTOV% <= 14.965\ngini = 0.27\nsamples = 56\nvalue = [47, 9]'),
#  Text(0.19426048565121412, 0.6739130434782609, 'away_last_50_OTOV% <= 13.105\ngini = 0.177\nsamples = 51\nvalue = [46, 5]'),
#  Text(0.188373804267844, 0.6304347826086957, 'home_last_3_PF <= 16.17\ngini = 0.115\nsamples = 49\nvalue = [46, 3]'),
#  Text(0.18248712288447388, 0.5869565217391305, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19426048565121412, 0.5869565217391305, 'home_last_3_3PA <= 43.165\ngini = 0.08\nsamples = 48\nvalue = [46, 2]'),
#  Text(0.188373804267844, 0.5434782608695652, 'away_last_50_FG <= 44.47\ngini = 0.042\nsamples = 47\nvalue = [46, 1]'),
#  Text(0.18248712288447388, 0.5, 'gini = 0.0\nsamples = 46\nvalue = [46, 0]'),
#  Text(0.19426048565121412, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20014716703458427, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20014716703458427, 0.6304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.21780721118469462, 0.6739130434782609, 'home_last_3_FTr <= 0.26\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.2119205298013245, 0.6304347826086957, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.22369389256806477, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.235467255334805, 0.717391304347826, 'home_last_10_ORtg <= 109.235\ngini = 0.444\nsamples = 15\nvalue = [5, 10]'),
#  Text(0.22958057395143489, 0.6739130434782609, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.24135393671817512, 0.6739130434782609, 'home_last_50_W <= 20.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.235467255334805, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.24724061810154527, 0.6304347826086957, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.27520235467255333, 0.8043478260869565, 'home_last_10_DFT/FGA <= 0.185\ngini = 0.473\nsamples = 141\nvalue = [54, 87]'),
#  Text(0.25901398086828553, 0.7608695652173914, 'home_last_10_STL <= 8.5\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.25312729948491536, 0.717391304347826, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.26490066225165565, 0.717391304347826, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2913907284768212, 0.7608695652173914, 'away_last_3_ORtg <= 126.9\ngini = 0.443\nsamples = 127\nvalue = [42, 85]'),
#  Text(0.2766740250183959, 0.717391304347826, 'home_last_50_ORtg <= 118.295\ngini = 0.42\nsamples = 120\nvalue = [36, 84]'),
#  Text(0.26490066225165565, 0.6739130434782609, 'away_last_3_BLK% <= 4.735\ngini = 0.386\nsamples = 111\nvalue = [29, 82]'),
#  Text(0.25901398086828553, 0.6304347826086957, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.27078734363502577, 0.6304347826086957, 'away_last_50_OppP <= 107.09\ngini = 0.358\nsamples = 107\nvalue = [25, 82]'),
#  Text(0.26490066225165565, 0.5869565217391305, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2766740250183959, 0.5869565217391305, 'home_last_10_DRtg <= 112.02\ngini = 0.334\nsamples = 104\nvalue = [22, 82]'),
#  Text(0.27078734363502577, 0.5434782608695652, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.282560706401766, 0.5434782608695652, 'away_last_10_BLK <= 6.75\ngini = 0.305\nsamples = 101\nvalue = [19, 82]'),
#  Text(0.2766740250183959, 0.5, 'away_last_3_3PA <= 43.5\ngini = 0.273\nsamples = 98\nvalue = [16, 82]'),
#  Text(0.27078734363502577, 0.45652173913043476, 'away_last_3_PF <= 15.5\ngini = 0.236\nsamples = 95\nvalue = [13, 82]'),
#  Text(0.2545989698307579, 0.41304347826086957, 'home_last_10_DDRB% <= 73.615\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.2487122884473878, 0.3695652173913043, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.26048565121412803, 0.3695652173913043, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2869757174392936, 0.41304347826086957, 'away_last_50_BLK% <= 6.675\ngini = 0.182\nsamples = 89\nvalue = [9, 80]'),
#  Text(0.27225901398086827, 0.3695652173913043, 'away_last_3_ORB <= 13.335\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.26637233259749815, 0.32608695652173914, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2781456953642384, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3016924208977189, 0.3695652173913043, 'away_last_3_DDRB% <= 71.785\ngini = 0.131\nsamples = 85\nvalue = [6, 79]'),
#  Text(0.2899190581309787, 0.32608695652173914, 'away_last_50_DDRB% <= 76.14\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.28403237674760856, 0.2826086956521739, 'away_last_50_STL% <= 7.36\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.2781456953642384, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2899190581309787, 0.2391304347826087, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2958057395143488, 0.2826086956521739, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.31346578366445915, 0.32608695652173914, 'away_last_3_OTOV% <= 7.335\ngini = 0.052\nsamples = 75\nvalue = [2, 73]'),
#  Text(0.30757910228108903, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.31935246504782927, 0.2826086956521739, 'away_last_3_DDRB% <= 85.085\ngini = 0.027\nsamples = 74\nvalue = [1, 73]'),
#  Text(0.31346578366445915, 0.2391304347826087, 'gini = 0.0\nsamples = 72\nvalue = [0, 72]'),
#  Text(0.3252391464311994, 0.2391304347826087, 'away_last_3_DDRB% <= 86.15\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.31935246504782927, 0.1956521739130435, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.33112582781456956, 0.1956521739130435, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.282560706401766, 0.45652173913043476, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2884473877851361, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2884473877851361, 0.6739130434782609, 'away_last_3_FG% <= 0.43\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.282560706401766, 0.6304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.29433406916850624, 0.6304347826086957, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.30610743193524653, 0.717391304347826, 'home_last_50_TRB <= 39.33\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.30022075055187636, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.31199411331861665, 0.6739130434782609, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.34142752023546724, 0.8478260869565217, 'home_last_3_FGA <= 99.665\ngini = 0.307\nsamples = 37\nvalue = [30, 7]'),
#  Text(0.3355408388520971, 0.8043478260869565, 'home_last_10_FG <= 40.9\ngini = 0.245\nsamples = 35\nvalue = [30, 5]'),
#  Text(0.3237674760853569, 0.7608695652173914, 'home_last_3_3P% <= 0.385\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.31788079470198677, 0.717391304347826, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.329654157468727, 0.717391304347826, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.34731420161883736, 0.7608695652173914, 'away_last_50_PF <= 18.15\ngini = 0.074\nsamples = 26\nvalue = [25, 1]'),
#  Text(0.34142752023546724, 0.717391304347826, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.35320088300220753, 0.717391304347826, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(0.34731420161883736, 0.8043478260869565, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5003046817512877, 0.8913043478260869, 'away_last_50_W <= 15.5\ngini = 0.449\nsamples = 777\nvalue = [264, 513]'),
#  Text(0.36497424576894777, 0.8478260869565217, 'home_last_3_P <= 100.5\ngini = 0.23\nsamples = 83\nvalue = [11, 72]'),
#  Text(0.35908756438557765, 0.8043478260869565, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3708609271523179, 0.8043478260869565, 'away_last_10_ORtg <= 105.07\ngini = 0.18\nsamples = 80\nvalue = [8, 72]'),
#  Text(0.36497424576894777, 0.7608695652173914, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.376747608535688, 0.7608695652173914, 'home_last_3_TRB <= 52.5\ngini = 0.142\nsamples = 78\nvalue = [6, 72]'),
#  Text(0.36497424576894777, 0.717391304347826, 'away_last_50_W <= 8.5\ngini = 0.101\nsamples = 75\nvalue = [4, 71]'),
#  Text(0.35908756438557765, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3708609271523179, 0.6739130434782609, 'away_last_10_AST <= 28.45\ngini = 0.078\nsamples = 74\nvalue = [3, 71]'),
#  Text(0.36497424576894777, 0.6304347826086957, 'home_last_50_FG <= 44.38\ngini = 0.053\nsamples = 73\nvalue = [2, 71]'),
#  Text(0.35320088300220753, 0.5869565217391305, 'away_last_3_DFT/FGA <= 0.33\ngini = 0.028\nsamples = 71\nvalue = [1, 70]'),
#  Text(0.34731420161883736, 0.5434782608695652, 'gini = 0.0\nsamples = 69\nvalue = [0, 69]'),
#  Text(0.35908756438557765, 0.5434782608695652, 'home_last_10_OeFG% <= 0.58\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.35320088300220753, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36497424576894777, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.376747608535688, 0.5869565217391305, 'away_last_50_FTr <= 0.285\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3708609271523179, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3826342899190581, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.376747608535688, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.38852097130242824, 0.717391304347826, 'home_last_3_DFT/FGA <= 0.185\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3826342899190581, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.39440765268579836, 0.6739130434782609, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6356351177336277, 0.8478260869565217, 'home_last_50_W <= 28.5\ngini = 0.463\nsamples = 694\nvalue = [253, 441]'),
#  Text(0.46534676232523914, 0.8043478260869565, 'home_last_50_FTA <= 21.04\ngini = 0.492\nsamples = 351\nvalue = [153, 198]'),
#  Text(0.423841059602649, 0.7608695652173914, 'away_last_10_3PA <= 31.45\ngini = 0.25\nsamples = 41\nvalue = [6, 35]'),
#  Text(0.41206769683590877, 0.717391304347826, 'home_last_50_BLK% <= 7.405\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.40618101545253865, 0.6739130434782609, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.4179543782192789, 0.6739130434782609, 'away_last_10_PF <= 21.3\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.41206769683590877, 0.6304347826086957, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.423841059602649, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.43561442236938924, 0.717391304347826, 'home_last_10_FT <= 12.7\ngini = 0.061\nsamples = 32\nvalue = [1, 31]'),
#  Text(0.4297277409860191, 0.6739130434782609, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.44150110375275936, 0.6739130434782609, 'gini = 0.0\nsamples = 31\nvalue = [0, 31]'),
#  Text(0.5068524650478293, 0.7608695652173914, 'home_last_50_STL% <= 6.105\ngini = 0.499\nsamples = 310\nvalue = [147, 163]'),
#  Text(0.45916114790286977, 0.717391304347826, 'home_last_3_PF <= 23.5\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.45327446651949965, 0.6739130434782609, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.4650478292862399, 0.6739130434782609, 'away_last_3_DeFG% <= 0.505\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.45916114790286977, 0.6304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.47093451066961, 0.6304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5545437821927888, 0.717391304347826, 'home_last_10_3P% <= 0.325\ngini = 0.496\nsamples = 295\nvalue = [134, 161]'),
#  Text(0.49448123620309054, 0.6739130434782609, 'away_last_10_DDRB% <= 73.96\ngini = 0.444\nsamples = 42\nvalue = [28, 14]'),
#  Text(0.48270787343635024, 0.6304347826086957, 'home_last_10_FT% <= 0.775\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.4768211920529801, 0.5869565217391305, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.48859455481972036, 0.5869565217391305, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.5062545989698307, 0.6304347826086957, 'away_last_3_AST% <= 51.965\ngini = 0.334\nsamples = 33\nvalue = [26, 7]'),
#  Text(0.5003679175864606, 0.5869565217391305, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5121412803532008, 0.5869565217391305, 'away_last_10_PF <= 17.4\ngini = 0.231\nsamples = 30\nvalue = [26, 4]'),
#  Text(0.5062545989698307, 0.5434782608695652, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5180279617365711, 0.5434782608695652, 'away_last_10_DRtg <= 120.38\ngini = 0.133\nsamples = 28\nvalue = [26, 2]'),
#  Text(0.5121412803532008, 0.5, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(0.5239146431199412, 0.5, 'away_last_10_FTA <= 19.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5180279617365711, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5298013245033113, 0.45652173913043476, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6146063281824872, 0.6739130434782609, 'away_last_10_TOV <= 11.95\ngini = 0.487\nsamples = 253\nvalue = [106, 147]'),
#  Text(0.5614422369389257, 0.6304347826086957, 'away_last_50_FTA <= 21.88\ngini = 0.476\nsamples = 59\nvalue = [36, 23]'),
#  Text(0.5445180279617365, 0.5869565217391305, 'away_last_3_DRtg <= 110.215\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.5386313465783664, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5504047093451067, 0.5434782608695652, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.5783664459161147, 0.5869565217391305, 'away_last_10_DDRB% <= 76.505\ngini = 0.431\nsamples = 51\nvalue = [35, 16]'),
#  Text(0.5621780721118469, 0.5434782608695652, 'away_last_3_TRB <= 41.665\ngini = 0.5\nsamples = 28\nvalue = [14, 14]'),
#  Text(0.5474613686534217, 0.5, 'home_last_3_ORB <= 15.335\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.5415746872700515, 0.45652173913043476, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.5533480500367918, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5768947755702722, 0.5, 'away_last_10_3P <= 11.2\ngini = 0.401\nsamples = 18\nvalue = [5, 13]'),
#  Text(0.565121412803532, 0.45652173913043476, 'away_last_50_FG <= 41.28\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.5592347314201619, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5710080941869021, 0.41304347826086957, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.5886681383370125, 0.45652173913043476, 'away_last_10_AST% <= 67.97\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.5827814569536424, 0.41304347826086957, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.5945548197203826, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5945548197203826, 0.5434782608695652, 'away_last_50_PF <= 20.93\ngini = 0.159\nsamples = 23\nvalue = [21, 2]'),
#  Text(0.5886681383370125, 0.5, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.6004415011037527, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6677704194260485, 0.6304347826086957, 'home_last_3_DDRB% <= 75.88\ngini = 0.461\nsamples = 194\nvalue = [70, 124]'),
#  Text(0.6181015452538632, 0.5869565217391305, 'home_last_3_ORB <= 9.165\ngini = 0.339\nsamples = 74\nvalue = [16, 58]'),
#  Text(0.6122148638704931, 0.5434782608695652, 'gini = 0.0\nsamples = 28\nvalue = [0, 28]'),
#  Text(0.6239882266372333, 0.5434782608695652, 'away_last_50_3P <= 11.12\ngini = 0.454\nsamples = 46\nvalue = [16, 30]'),
#  Text(0.6122148638704931, 0.5, 'away_last_3_3PA <= 28.17\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.6063281824871228, 0.45652173913043476, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6181015452538632, 0.45652173913043476, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.6357615894039735, 0.5, 'home_last_10_ORtg <= 112.31\ngini = 0.327\nsamples = 34\nvalue = [7, 27]'),
#  Text(0.6298749080206034, 0.45652173913043476, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6416482707873437, 0.45652173913043476, 'away_last_10_STL% <= 5.69\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.6357615894039735, 0.41304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6475349521707138, 0.41304347826086957, 'away_last_3_OeFG% <= 0.635\ngini = 0.069\nsamples = 28\nvalue = [1, 27]'),
#  Text(0.6416482707873437, 0.3695652173913043, 'gini = 0.0\nsamples = 27\nvalue = [0, 27]'),
#  Text(0.6534216335540839, 0.3695652173913043, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.717439293598234, 0.5869565217391305, 'home_last_3_DTOV% <= 13.985\ngini = 0.495\nsamples = 120\nvalue = [54, 66]'),
#  Text(0.7019867549668874, 0.5434782608695652, 'home_last_3_DRtg <= 123.4\ngini = 0.498\nsamples = 88\nvalue = [47, 41]'),
#  Text(0.6961000735835173, 0.5, 'away_last_50_TRB% <= 52.645\ngini = 0.487\nsamples = 81\nvalue = [47, 34]'),
#  Text(0.6902133922001472, 0.45652173913043476, 'away_last_10_3P <= 10.55\ngini = 0.468\nsamples = 75\nvalue = [47, 28]'),
#  Text(0.6710816777041942, 0.41304347826086957, 'away_last_10_3PAr <= 0.325\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.6651949963208241, 0.3695652173913043, 'away_last_10_FTA <= 23.05\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.659308314937454, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6710816777041942, 0.32608695652173914, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6769683590875644, 0.3695652173913043, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.7093451066961001, 0.41304347826086957, 'away_last_10_DRtg <= 114.95\ngini = 0.421\nsamples = 63\nvalue = [44, 19]'),
#  Text(0.6887417218543046, 0.3695652173913043, 'home_last_50_FT <= 20.16\ngini = 0.219\nsamples = 32\nvalue = [28, 4]'),
#  Text(0.6828550404709345, 0.32608695652173914, 'away_last_10_OORB% <= 18.73\ngini = 0.124\nsamples = 30\nvalue = [28, 2]'),
#  Text(0.6769683590875644, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6887417218543046, 0.2826086956521739, 'home_last_50_OFT/FGA <= 0.185\ngini = 0.067\nsamples = 29\nvalue = [28, 1]'),
#  Text(0.6828550404709345, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6946284032376747, 0.2391304347826087, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(0.6946284032376747, 0.32608695652173914, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7299484915378955, 0.3695652173913043, 'home_last_50_FG <= 41.65\ngini = 0.499\nsamples = 31\nvalue = [16, 15]'),
#  Text(0.7181751287711553, 0.32608695652173914, 'home_last_50_3P% <= 0.375\ngini = 0.36\nsamples = 17\nvalue = [4, 13]'),
#  Text(0.7122884473877852, 0.2826086956521739, 'home_last_10_BLK% <= 12.795\ngini = 0.133\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.7064017660044151, 0.2391304347826087, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.7181751287711553, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7240618101545254, 0.2826086956521739, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7417218543046358, 0.32608695652173914, 'away_last_3_FTr <= 0.325\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.7358351729212657, 0.2826086956521739, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.7476085356880059, 0.2826086956521739, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7019867549668874, 0.45652173913043476, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.7078734363502576, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.7328918322295805, 0.5434782608695652, 'away_last_50_STL <= 6.45\ngini = 0.342\nsamples = 32\nvalue = [7, 25]'),
#  Text(0.7270051508462104, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7387785136129507, 0.5, 'away_last_10_DeFG% <= 0.515\ngini = 0.238\nsamples = 29\nvalue = [4, 25]'),
#  Text(0.7270051508462104, 0.45652173913043476, 'away_last_50_P <= 109.75\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.7211184694628403, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7328918322295805, 0.41304347826086957, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7505518763796909, 0.45652173913043476, 'away_last_10_FGA <= 93.0\ngini = 0.077\nsamples = 25\nvalue = [1, 24]'),
#  Text(0.7446651949963208, 0.41304347826086957, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.7564385577630611, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8059234731420162, 0.8043478260869565, 'home_last_50_AST% <= 68.38\ngini = 0.413\nsamples = 343\nvalue = [100, 243]'),
#  Text(0.8000367917586461, 0.7608695652173914, 'away_last_3_DDRB% <= 70.55\ngini = 0.4\nsamples = 336\nvalue = [93, 243]'),
#  Text(0.7350993377483444, 0.717391304347826, 'away_last_50_W <= 30.5\ngini = 0.472\nsamples = 21\nvalue = [13, 8]'),
#  Text(0.7292126563649742, 0.6739130434782609, 'away_last_3_Pace <= 99.5\ngini = 0.305\nsamples = 16\nvalue = [13, 3]'),
#  Text(0.7233259749816041, 0.6304347826086957, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.7350993377483444, 0.6304347826086957, 'away_last_50_TRB <= 42.48\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.7292126563649742, 0.5869565217391305, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7409860191317145, 0.5869565217391305, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7409860191317145, 0.6739130434782609, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8649742457689478, 0.717391304347826, 'away_last_50_DDRB% <= 77.395\ngini = 0.379\nsamples = 315\nvalue = [80, 235]'),
#  Text(0.7939661515820456, 0.6739130434782609, 'away_last_3_FG <= 36.5\ngini = 0.285\nsamples = 180\nvalue = [31, 149]'),
#  Text(0.7586460632818248, 0.6304347826086957, 'away_last_50_AST% <= 60.455\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.7527593818984547, 0.5869565217391305, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.7645327446651949, 0.5869565217391305, 'home_last_50_PF <= 18.06\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.7586460632818248, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7704194260485652, 0.5434782608695652, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8292862398822664, 0.6304347826086957, 'home_last_50_DTOV% <= 13.39\ngini = 0.251\nsamples = 170\nvalue = [25, 145]'),
#  Text(0.7998528329654158, 0.5869565217391305, 'away_last_10_AST% <= 52.49\ngini = 0.206\nsamples = 154\nvalue = [18, 136]'),
#  Text(0.7821927888153054, 0.5434782608695652, 'home_last_50_DRtg <= 115.36\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.7763061074319353, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7880794701986755, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8175128771155261, 0.5434782608695652, 'home_last_50_3P <= 15.71\ngini = 0.18\nsamples = 150\nvalue = [15, 135]'),
#  Text(0.7998528329654158, 0.5, 'home_last_50_OORB% <= 18.74\ngini = 0.135\nsamples = 137\nvalue = [10, 127]'),
#  Text(0.7939661515820456, 0.45652173913043476, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8057395143487859, 0.45652173913043476, 'away_last_50_H <= 19.5\ngini = 0.124\nsamples = 136\nvalue = [9, 127]'),
#  Text(0.7998528329654158, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.811626195732156, 0.41304347826086957, 'away_last_10_ORtg <= 127.16\ngini = 0.111\nsamples = 135\nvalue = [8, 127]'),
#  Text(0.8057395143487859, 0.3695652173913043, 'home_last_10_BLK <= 2.55\ngini = 0.099\nsamples = 134\nvalue = [7, 127]'),
#  Text(0.7998528329654158, 0.32608695652173914, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.811626195732156, 0.32608695652173914, 'away_last_3_DDRB% <= 83.4\ngini = 0.086\nsamples = 133\nvalue = [6, 127]'),
#  Text(0.8057395143487859, 0.2826086956521739, 'away_last_3_DFT/FGA <= 0.395\ngini = 0.073\nsamples = 132\nvalue = [5, 127]'),
#  Text(0.7998528329654158, 0.2391304347826087, 'home_last_3_OppP <= 97.165\ngini = 0.059\nsamples = 131\nvalue = [4, 127]'),
#  Text(0.7939661515820456, 0.1956521739130435, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8057395143487859, 0.1956521739130435, 'away_last_10_FT% <= 0.7\ngini = 0.045\nsamples = 130\nvalue = [3, 127]'),
#  Text(0.7910228108903605, 0.15217391304347827, 'away_last_50_P <= 115.23\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7851361295069904, 0.10869565217391304, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7969094922737306, 0.10869565217391304, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8204562178072112, 0.15217391304347827, 'away_last_3_STL% <= 4.0\ngini = 0.031\nsamples = 128\nvalue = [2, 126]'),
#  Text(0.8086828550404709, 0.10869565217391304, 'home_last_50_OFT/FGA <= 0.22\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8027961736571008, 0.06521739130434782, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8145695364238411, 0.06521739130434782, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8322295805739515, 0.10869565217391304, 'away_last_50_Pace <= 94.665\ngini = 0.016\nsamples = 126\nvalue = [1, 125]'),
#  Text(0.8263428991905813, 0.06521739130434782, 'away_last_50_W <= 28.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8204562178072112, 0.021739130434782608, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8322295805739515, 0.021739130434782608, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8381162619573216, 0.06521739130434782, 'gini = 0.0\nsamples = 123\nvalue = [0, 123]'),
#  Text(0.811626195732156, 0.2391304347826087, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8175128771155261, 0.2826086956521739, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8175128771155261, 0.3695652173913043, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8351729212656365, 0.5, 'away_last_3_ORtg <= 117.8\ngini = 0.473\nsamples = 13\nvalue = [5, 8]'),
#  Text(0.8292862398822664, 0.45652173913043476, 'away_last_3_H <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.8233995584988962, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8351729212656365, 0.41304347826086957, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8410596026490066, 0.45652173913043476, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.8587196467991169, 0.5869565217391305, 'away_last_10_OORB% <= 21.58\ngini = 0.492\nsamples = 16\nvalue = [7, 9]'),
#  Text(0.8528329654157468, 0.5434782608695652, 'away_last_3_AST <= 24.665\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.8469462840323767, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8587196467991169, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.8646063281824872, 0.5434782608695652, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.9359823399558499, 0.6739130434782609, 'home_last_10_FGA <= 89.15\ngini = 0.462\nsamples = 135\nvalue = [49, 86]'),
#  Text(0.9013980868285504, 0.6304347826086957, 'away_last_3_OORB% <= 19.785\ngini = 0.5\nsamples = 85\nvalue = [42, 43]'),
#  Text(0.8822663723325975, 0.5869565217391305, 'away_last_50_TRB <= 42.11\ngini = 0.266\nsamples = 19\nvalue = [3, 16]'),
#  Text(0.8763796909492274, 0.5434782608695652, 'away_last_10_DRtg <= 112.915\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.8704930095658573, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8822663723325975, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8881530537159676, 0.5434782608695652, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.9205298013245033, 0.5869565217391305, 'home_last_3_FTA <= 22.165\ngini = 0.483\nsamples = 66\nvalue = [39, 27]'),
#  Text(0.8999264164827079, 0.5434782608695652, 'home_last_50_ORtg <= 116.935\ngini = 0.444\nsamples = 24\nvalue = [8, 16]'),
#  Text(0.8940397350993378, 0.5, 'home_last_3_DDRB% <= 76.265\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.8881530537159676, 0.45652173913043476, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.8999264164827079, 0.45652173913043476, 'home_last_10_BLK <= 5.7\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.8940397350993378, 0.41304347826086957, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.905813097866078, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.905813097866078, 0.5, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.9411331861662987, 0.5434782608695652, 'away_last_10_TOV <= 13.45\ngini = 0.387\nsamples = 42\nvalue = [31, 11]'),
#  Text(0.9293598233995585, 0.5, 'away_last_10_DRtg <= 109.135\ngini = 0.142\nsamples = 26\nvalue = [24, 2]'),
#  Text(0.9234731420161884, 0.45652173913043476, 'away_last_3_FT <= 17.665\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9175864606328182, 0.41304347826086957, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9293598233995585, 0.41304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9352465047829286, 0.45652173913043476, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]'),
#  Text(0.9529065489330389, 0.5, 'away_last_50_OTOV% <= 12.44\ngini = 0.492\nsamples = 16\nvalue = [7, 9]'),
#  Text(0.9470198675496688, 0.45652173913043476, 'home_last_50_DDRB% <= 78.6\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.9411331861662987, 0.41304347826086957, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.9529065489330389, 0.41304347826086957, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9587932303164092, 0.45652173913043476, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.9705665930831494, 0.6304347826086957, 'away_last_3_3P <= 14.165\ngini = 0.241\nsamples = 50\nvalue = [7, 43]'),
#  Text(0.9587932303164092, 0.5869565217391305, 'home_last_10_H <= 2.5\ngini = 0.054\nsamples = 36\nvalue = [1, 35]'),
#  Text(0.9529065489330389, 0.5434782608695652, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9646799116997793, 0.5434782608695652, 'gini = 0.0\nsamples = 35\nvalue = [0, 35]'),
#  Text(0.9823399558498896, 0.5869565217391305, 'away_last_3_FT% <= 0.785\ngini = 0.49\nsamples = 14\nvalue = [6, 8]'),
#  Text(0.9764532744665195, 0.5434782608695652, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.9882266372332598, 0.5434782608695652, 'away_last_10_3PAr <= 0.42\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.9823399558498896, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9941133186166299, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.8118101545253863, 0.7608695652173914, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]')]
