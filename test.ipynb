# %%
import pandas as pd

df = pd.read_csv('./data/dataset.csv')
df.head()
# Out:
#    Unnamed: 0  home_last_3_OppP  home_last_3_FG  home_last_3_FGA  \
# 0           0            106.33           42.33            84.67
# 1           0            104.33           44.00            94.67
# 2           0            120.00           46.67            90.67
# 3           0            109.67           42.67            89.33
# 4           0            110.33           43.00            87.00
#
#    home_last_3_FG%  home_last_3_3P  home_last_3_3PA  home_last_3_3P%  \
# 0             0.50           11.33            31.33             0.36
# 1             0.47            8.67            29.67             0.29
# 2             0.51           14.67            37.33             0.39
# 3             0.48           15.33            38.33             0.40
# 4             0.49           13.67            38.67             0.35
#
#    home_last_3_FT  home_last_3_FTA  ...  away_last_50_DeFG%  \
# 0           16.33            22.67  ...                0.51
# ...

# %%
print("Varun")
# Out:
# Varun
