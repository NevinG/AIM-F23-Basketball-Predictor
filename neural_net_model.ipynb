# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.14.0

# %%
#necessary imports
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
#import dataset
df = pd.read_csv('./data/dataset.csv')
df.head()
# Out:
#    Unnamed: 0  home_last_3_P  home_last_3_OppP  home_last_3_FG  \
# 0           0         112.33            106.33           42.33
# 1           0         110.67            114.33           41.33
# 2           0         113.67            113.33           44.00
# 3           0         116.33            117.67           44.33
# 4           0         120.67            112.33           43.00
#
#    home_last_3_FGA  home_last_3_FG%  home_last_3_3P  home_last_3_3PA  \
# 0            84.67             0.50           11.33            31.33
# 1            90.67             0.46           11.33            31.33
# 2            92.67             0.48           10.33            29.00
# 3            95.33             0.47           14.33            38.00
# 4            89.00             0.49           13.33            31.33
#
#    home_last_3_3P%  home_last_3_FT  ...  away_last_50_DeFG%  \
# 0             0.36           16.33  ...                0.51
# 1             0.34           16.67  ...                0.53
# 2             0.34           15.33  ...                0.53
# 3             0.39           13.33  ...                0.50
# 4             0.42           21.33  ...                0.54
#
#    away_last_50_DTOV%  away_last_50_DDRB%  away_last_50_DFT/FGA  \
# 0               12.67               76.90                  0.18
# 1               11.26               77.10                  0.21
# 2               11.25               75.18                  0.17
# 3               11.99               76.40                  0.16
# 4               13.79               74.56                  0.21
#
#    away_last_50_W  away_last_50_H        Date  Home_Team  Away_Team  \
# 0            41.0            27.0  2022-02-03        ATL        PHO
# 1            18.0            26.0  2022-02-08        ATL        IND
# 2            19.0            26.0  2022-02-11        ATL        SAS
# 3            32.0            25.0  2022-02-15        ATL        CLE
# 4            27.0            24.0  2022-02-26        ATL        TOR
#
#    Home_Team_Won
# 0           True
# 1           True
# 2          False
# 3           True
# 4           True
#
# [5 rows x 233 columns]

# %%
#We want clean the data and split up the input and output
target_column = "Home_Team_Won"
unneeded_columns = ["Date",	"Home_Team", "Away_Team"]

#remove first column from dataset
df = df.drop(df.columns[[0]],axis = 1)

#remove unneed_columns. These are columns that are in our dataset, but we don't want to feed into the model
#this is because they are categorical, we're only feeding our model numerical data
clean_df = df.drop(columns=unneeded_columns, axis=1)

# making new data frame with dropped NA values
clean_df = clean_df.dropna(axis=0, how='any')

#get the output rows of the dataset
output_rows = clean_df[target_column]

#remove output rows from the dataset
clean_df = clean_df.drop(columns=target_column, axis=1)

clean_df.head()
# Out:
#    home_last_3_P  home_last_3_OppP  home_last_3_FG  home_last_3_FGA  \
# 0         112.33            106.33           42.33            84.67
# 1         110.67            114.33           41.33            90.67
# 2         113.67            113.33           44.00            92.67
# 3         116.33            117.67           44.33            95.33
# 4         120.67            112.33           43.00            89.00
#
#    home_last_3_FG%  home_last_3_3P  home_last_3_3PA  home_last_3_3P%  \
# 0             0.50           11.33            31.33             0.36
# 1             0.46           11.33            31.33             0.34
# 2             0.48           10.33            29.00             0.34
# 3             0.47           14.33            38.00             0.39
# 4             0.49           13.33            31.33             0.42
#
#    home_last_3_FT  home_last_3_FTA  ...  away_last_50_OeFG%  \
# 0           16.33            22.67  ...                0.54
# 1           16.67            19.67  ...                0.52
# 2           15.33            17.67  ...                0.52
# 3           13.33            15.33  ...                0.54
# 4           21.33            27.33  ...                0.51
#
#    away_last_50_OTOV%  away_last_50_OORB%  away_last_50_OFT/FGA  \
# 0               11.55               22.63                  0.18
# 1               11.71               25.02                  0.18
# 2               10.79               24.07                  0.15
# 3               12.56               23.80                  0.19
# 4               10.69               27.32                  0.18
#
#    away_last_50_DeFG%  away_last_50_DTOV%  away_last_50_DDRB%  \
# 0                0.51               12.67               76.90
# 1                0.53               11.26               77.10
# 2                0.53               11.25               75.18
# 3                0.50               11.99               76.40
# 4                0.54               13.79               74.56
#
#    away_last_50_DFT/FGA  away_last_50_W  away_last_50_H
# 0                  0.18            41.0            27.0
# 1                  0.21            18.0            26.0
# 2                  0.17            19.0            26.0
# 3                  0.16            32.0            25.0
# 4                  0.21            27.0            24.0
#
# [5 rows x 228 columns]

# %%
#we are going to normalize our data. We want to feed our model normalized data anyways
scaler = MinMaxScaler()

scaler.fit(clean_df)
norm_df = scaler.transform(clean_df)

#we cleaned up our data, now we are going to split it and get it ready to feed into the model
X_train, X_test, y_train, y_test = train_test_split(norm_df, output_rows, test_size=0.25, random_state=0)

#now we have our training and testing dataset
print('X_train:',np.shape(X_train))
print('y_train:',np.shape(y_train))
print('X_test:',np.shape(X_test))
print('y_test:',np.shape(y_test))
# Out:
# X_train: (1274, 228)
# y_train: (1274,)
# X_test: (425, 228)
# y_test: (425,)

# %%
#create and compile model

#we have a neural network with 1 input layer, 0 hidden layers, and 1 output layer
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=228, activation='relu', input_shape=(228,)))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

#add optimizer
adam = tf.keras.optimizers.Adam(learning_rate=0.001)

#compile model
model.compile(loss='binary_crossentropy', optimizer=adam, metrics=["accuracy"])

# %%
#train the model
model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 1s 2ms/step - loss: 0.6833 - accuracy: 0.5604
# Epoch 2/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6512 - accuracy: 0.6201
# Epoch 3/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6472 - accuracy: 0.6327
# Epoch 4/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6473 - accuracy: 0.6374
# Epoch 5/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6497 - accuracy: 0.6224
# Epoch 6/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.6376 - accuracy: 0.6476
# Epoch 7/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.6299 - accuracy: 0.6460
# Epoch 8/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6387 - accuracy: 0.6358
# Epoch 9/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6333 - accuracy: 0.6468
# Epoch 10/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6429 - accuracy: 0.6272
# Epoch 11/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6287 - accuracy: 0.6515
# Epoch 12/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6355 - accuracy: 0.6374
# Epoch 13/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6214 - accuracy: 0.6570
# Epoch 14/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6207 - accuracy: 0.6546
# Epoch 15/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6272 - accuracy: 0.6405
# Epoch 16/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6229 - accuracy: 0.6554
# Epoch 17/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6222 - accuracy: 0.6586
# Epoch 18/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6261 - accuracy: 0.6476
# Epoch 19/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6161 - accuracy: 0.6601
# Epoch 20/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6103 - accuracy: 0.6617
# Epoch 21/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6119 - accuracy: 0.6664
# Epoch 22/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6073 - accuracy: 0.6672
# Epoch 23/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.6037 - accuracy: 0.6797
# Epoch 24/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.6111 - accuracy: 0.6641
# Epoch 25/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.6043 - accuracy: 0.6633
# Epoch 26/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6078 - accuracy: 0.6703
# Epoch 27/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6009 - accuracy: 0.6813
# Epoch 28/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5967 - accuracy: 0.6845
# Epoch 29/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6009 - accuracy: 0.6837
# Epoch 30/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6023 - accuracy: 0.6703
# Epoch 31/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6019 - accuracy: 0.6641
# Epoch 32/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.6001 - accuracy: 0.6743
# Epoch 33/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5855 - accuracy: 0.6876
# Epoch 34/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5964 - accuracy: 0.6790
# Epoch 35/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5884 - accuracy: 0.6892
# Epoch 36/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5892 - accuracy: 0.6876
# Epoch 37/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5822 - accuracy: 0.6923
# Epoch 38/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5867 - accuracy: 0.6782
# Epoch 39/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5813 - accuracy: 0.6970
# Epoch 40/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5723 - accuracy: 0.6915
# Epoch 41/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5789 - accuracy: 0.6907
# Epoch 42/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5765 - accuracy: 0.6923
# Epoch 43/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5691 - accuracy: 0.7002
# Epoch 44/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5681 - accuracy: 0.6939
# Epoch 45/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5583 - accuracy: 0.7096
# Epoch 46/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5581 - accuracy: 0.7049
# Epoch 47/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5553 - accuracy: 0.7111
# Epoch 48/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5562 - accuracy: 0.7104
# Epoch 49/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5596 - accuracy: 0.7041
# Epoch 50/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5572 - accuracy: 0.7041
# Epoch 51/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5480 - accuracy: 0.7245
# Epoch 52/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5549 - accuracy: 0.7135
# Epoch 53/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5372 - accuracy: 0.7190
# Epoch 54/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5323 - accuracy: 0.7300
# Epoch 55/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5344 - accuracy: 0.7339
# Epoch 56/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5318 - accuracy: 0.7331
# Epoch 57/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5444 - accuracy: 0.7119
# Epoch 58/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5255 - accuracy: 0.7402
# Epoch 59/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.5253 - accuracy: 0.7261
# Epoch 60/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5166 - accuracy: 0.7386
# Epoch 61/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5104 - accuracy: 0.7433
# Epoch 62/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5113 - accuracy: 0.7543
# Epoch 63/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5066 - accuracy: 0.7457
# Epoch 64/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4993 - accuracy: 0.7582
# Epoch 65/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4874 - accuracy: 0.7755
# Epoch 66/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4872 - accuracy: 0.7692
# Epoch 67/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4971 - accuracy: 0.7598
# Epoch 68/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.5005 - accuracy: 0.7543
# Epoch 69/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4836 - accuracy: 0.7677
# Epoch 70/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4718 - accuracy: 0.7802
# Epoch 71/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4744 - accuracy: 0.7708
# Epoch 72/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4800 - accuracy: 0.7794
# Epoch 73/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4840 - accuracy: 0.7590
# Epoch 74/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4603 - accuracy: 0.7810
# Epoch 75/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4752 - accuracy: 0.7794
# Epoch 76/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4690 - accuracy: 0.7747
# Epoch 77/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4560 - accuracy: 0.7951
# Epoch 78/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4535 - accuracy: 0.8046
# Epoch 79/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4722 - accuracy: 0.7755
# Epoch 80/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4487 - accuracy: 0.7943
# Epoch 81/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4362 - accuracy: 0.8155
# Epoch 82/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4312 - accuracy: 0.8116
# Epoch 83/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4487 - accuracy: 0.8046
# Epoch 84/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4319 - accuracy: 0.8014
# Epoch 85/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4372 - accuracy: 0.8030
# Epoch 86/100
# 40/40 [==============================] - 0s 1ms/step - loss: 0.4219 - accuracy: 0.8218
# Epoch 87/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4202 - accuracy: 0.8124
# Epoch 88/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4171 - accuracy: 0.8116
# Epoch 89/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4096 - accuracy: 0.8155
# Epoch 90/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4122 - accuracy: 0.8132
# Epoch 91/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4222 - accuracy: 0.8132
# Epoch 92/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4040 - accuracy: 0.8163
# Epoch 93/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.4073 - accuracy: 0.8100
# Epoch 94/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3904 - accuracy: 0.8430
# Epoch 95/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3947 - accuracy: 0.8367
# Epoch 96/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3875 - accuracy: 0.8273
# Epoch 97/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3968 - accuracy: 0.8273
# Epoch 98/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3935 - accuracy: 0.8399
# Epoch 99/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3673 - accuracy: 0.8571
# Epoch 100/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3605 - accuracy: 0.8564

# %%
#evaluate model
loss_and_metrics = model.evaluate(X_test, y_test)
print(loss_and_metrics)
print('Loss = ',loss_and_metrics[0])
print('Accuracy = ',loss_and_metrics[1])
# Out:
# 14/14 [==============================] - 0s 1ms/step - loss: 0.7653 - accuracy: 0.5953
# [0.7652770280838013, 0.5952941179275513]
# Loss =  0.7652770280838013
# Accuracy =  0.5952941179275513

# %%
#prediction and evaluation
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix


predicted = model.predict(X_test)
predicted = tf.squeeze(predicted)
predicted = np.array([1 if x >= 0.5 else 0 for x in predicted])
actual = np.array(y_test)
conf_mat = confusion_matrix(actual, predicted)
displ = ConfusionMatrixDisplay(confusion_matrix=conf_mat)
displ.plot()
# Out:
# 14/14 [==============================] - 0s 1ms/step
